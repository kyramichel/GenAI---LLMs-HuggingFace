# %% [markdown]
# # Music Generation from text
#
# sing Mubert API www.mubert.com

# %% [markdown]
# ## 1.Go to Huggingface https://huggingface.co/spaces/Mubert/Text-to-Music
#
# ## 2.Insert text in Prompt
# ## 3.Click Submit to generate music based on your text
# ## 4.Play the music
# ## 5.Download the .mp3 music file that you generated

# %% [markdown]
# ![TextMusic.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Prompts to try:
#
# relaxing ocean sounds
#
# soundtrack music for studying
#
# electronic music for studying
#
# electronic space music
