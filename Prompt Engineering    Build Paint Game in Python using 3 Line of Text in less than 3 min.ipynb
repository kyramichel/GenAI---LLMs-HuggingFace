# %% [markdown]
# # Prompt Engineering - Build Games in Python with few lines of text
#
# ## Let's Build classic Paint Games with just 3 lines of text

# %%
pip install pygame

# %%
import pygame

# %% [markdown]
# Go to OpenAI and create an account and generate a Key
#
# Click on Playgpround https://beta.openai.com/playground

# %% [markdown]
# ![playground.jpg](attachment:playground.jpg)

# %% [markdown]
# # Build the Paint Game
#
# with the following 3 lines of code:

# %%
def paint_game():
    # Initialize pygame 
    pygame.init() 
    # set the window size 
    window_width=500
    window_height=500
    # Create window of size (window_width, window_height) 
    screen = pygame.display.set_mode((window_width, window_height)) 
    # Set window title 
    pygame.display.set_caption("Paint Game") 
    # Set background color to white 
    screen.fill((255, 255, 255)) 
    # Initialize brush size, color, and brush type 
    brush_size = 5 
    brush_color = (0, 0, 0) 
    brush_type = 'circle' 
 
    # Define a function to draw on the surface object 
    def draw_on_screen(surface, color, size, pos, type): 
        # Check the brush type 
        if (type == 'circle'): 
            # Draw a circle on screen 
            pygame.draw.circle(surface, color, pos, size) 
 
    # Run until the user asks to quit 
    running = True
    while running: 
        # Iterate over the list of Event objects 
        # that was returned by pygame.event.get() method. 
        for event in pygame.event.get(): 
            # If user clicks the quit button, stop the loop 
            if event.type == pygame.QUIT: 
                running = False
            # Check if the user presses mouse 
            if pygame.mouse.get_pressed()[0]: 
                # Get mouse position 
                pos = pygame.mouse.get_pos() 
                # Draw on the screen 
                draw_on_screen(screen, brush_color, brush_size, pos, brush_type) 
        # Update the window 
        pygame.display.update() 
    # Unintialize all pygame modules 
    pygame.quit()

# %%
# Call the paint_game function 
paint_game()

# %% [markdown]
# # Game is built.
#
# A Pain Game window will pop up -> where you can start drawing

# %% [markdown]
# Remark: The Python game weas built in less than 3 min with only 3 lines of text!
