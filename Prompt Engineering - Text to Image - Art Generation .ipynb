# %% [markdown]
# # Prompt Engineering: Art Generation - Text to Image
#
# The idea beind Prompt Engineering is to be able to make anything from text description
#
#
#
# ### Here I will show how to  generate art images and animations by typing 1 sentence!
#
# using CLIP (https://github.com/openai/CLIP), a Neural Network by OpenAI that coverts text with image.
#
#
# ### To generate cool art images (and animations)
#
# using this OpenAI NN that can be trained on a variety datasets: eg wikipedia, etc
# (by default: Imagenet 16384 www.image-net.org):

# %% [markdown]
# ### Go to Google Colab
#
#
# ### Click on
# https://colab.research.google.com/drive/1lx9AGsrh7MlyJhK9UrNTK8pYpARnx457#scrollTo=1tthw0YaispD
#
# to open the notebook VQGAN+CLIP.ipynb from:
#
#
# ### Run cells: 1), 2) and 3) up to the Prompt cell 4).

# %% [markdown]
#
#
# # 4) Art Generator Parameters
#
#
# This cell is for Prompting  (where you type your text)

# %% [markdown]
# ### To create an art image inspired by Dali
#
# I typed the following line in the text (and left everything else the default setting):
#
#
# Text: "The Persistence of Memory by Salvador Dali"
#
# height:500
#
# width:500
# ....

# %% [markdown]
# ### Run cell 4) then go to cell:
#
# ### 5) Run the Art Generator :)
#
# and the following image was created  - from 1 line of text: "The Persistence of Memory by Salvador Dali"

# %% [markdown]
# ![dale2.png](attachment:dale2.png)

# %% [markdown]
# ![dale.png](attachment:dale.png)

# %% [markdown]
# I also created an art vido clip by running the
#
# ## Optional Step --- Generate a video from generated frames

# %% [markdown]
# # Another Prompt:
#
# Reload the google colab
#
# Go to cell 4) Art Generator Parameters  --> click on it
#
# Go to Runtime tab --> click Run Before (run anyway)

# %% [markdown]
# ### Let's do some Van Gogh art!
#
#
# Reload Google Colab, then run cells: 1), 2) and 3) up to the Prompt cell 4)
#
#
# # 4) Art Generator Parameters
#
# text = "Starry Night by Vincent van Gogh" '
#
# height:500
#
# width:500
# ....'

# %% [markdown]
# Run cell 4) then run cell 5) Run the Art Generator :)

# %% [markdown]
# The following image was generated from text: "Starry Night by Vincent van Gogh":

# %% [markdown]
# ![vgogh1.jpg](attachment:vgogh1.jpg)

# %% [markdown]
# ![vgogh2.jpg](attachment:vgogh2.jpg)

# %% [markdown]
# # Another Prompt:
#
# Reload the google colab. Now let's build a sun art image inspired by Van Gogh:

# %% [markdown]
# ![sunVG1.jpg](attachment:sunVG1.jpg)

# %% [markdown]
# ![SunVG2.png](attachment:SunVG2.png)

# %% [markdown]
# ## Remark:
#
# You can try additional features and/or using different datasets.
#
# Also you can enhance your image:  click in cell 18) Want to Super-Enhance the Generated Image with another advanced A.I.? Enhances a 500x500 image to 1760x1760 with no quality loss!!!
#
# You can also protect your image: click in cell 20) Want to share your art, but dont want anyone to steal it? Watermark it using this colab..

# %% [markdown]
# ### Remark
#
# Without knowing anything about arts or programming, anyone can generate cool art images and animations from text description.
